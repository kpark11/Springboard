# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
filenames = [x for x in os.listdir() if re.search('.XPT',x)]
filenames
# Out:
# ['FASTQX_D.XPT',
#  'FASTQX_E.XPT',
#  'FASTQX_F.XPT',
#  'FASTQX_G.XPT',
#  'FASTQX_H.XPT',
#  'FASTQX_I.XPT',
#  'PH.XPT',
#  'PH_B.XPT',
#  'PH_C.XPT',
#  'P_FASTQX.XPT']

# %%
total_df = pd.DataFrame()
for i in range(len(filenames)):
    if filenames[i] == 'FASTQX_E.XPT':
        year = 2007
    elif filenames[i] == 'PH.XPT':
        year = 1999
    elif filenames[i] == 'FASTQX_D.XPT':
        year = 2005
    elif filenames[i] == 'PH_B.XPT':
        year = 2001
    elif filenames[i] == 'PH_C.XPT':
        year = 2003
    elif filenames[i] == 'FASTQX_F.XPT':
        year = 2009
    elif filenames[i] == 'FASTQX_G.XPT':
        year = 2011
    elif filenames[i] == 'FASTQX_H.XPT':
        year = 2013
    elif filenames[i] == 'FASTQX_I.XPT':
        year = 2015
    elif filenames[i] == 'FASTQX_J.XPT':
        year = 2017
    elif filenames[i] == 'P_FASTQX.XPT':
        year = 2017
    df = pd.read_sas(filenames[i])
    df['year'] = year
    total_df = pd.concat([df,total_df],ignore_index=True,sort=False)
    
    print(df.head())
    
    print(total_df.tail())
# Out:
#       SEQN  PHQ020  PHACOFHR  PHACOFMN  PHQ030  PHAALCHR  PHAALCMN  PHQ040  \
# 0  31128.0     2.0       NaN       NaN     2.0       NaN       NaN     2.0
# 1  31129.0     2.0       NaN       NaN     2.0       NaN       NaN     2.0
# 2  31130.0     2.0       NaN       NaN     2.0       NaN       NaN     2.0
# 3  31131.0     2.0       NaN       NaN     2.0       NaN       NaN     2.0
# 4  31132.0     2.0       NaN       NaN     2.0       NaN       NaN     2.0
#
#    PHAGUMHR  PHAGUMMN  PHQ050  PHAANTHR  PHAANTMN  PHQ060  PHASUPHR  \
# 0       NaN       NaN     2.0       NaN       NaN     2.0       NaN
# 1       NaN       NaN     2.0       NaN       NaN     2.0       NaN
# 2       NaN       NaN     2.0       NaN       NaN     2.0       NaN
# 3       NaN       NaN     2.0       NaN       NaN     2.0       NaN
# 4       NaN       NaN     2.0       NaN       NaN     1.0       1.0
#
#        PHASUPMN  PHAFSTHR  PHAFSTMN       PHDSESN  year
# ...

# %%
total_df
# Out:
#            SEQN  PHQ020  PHACOFHR  PHACOFMN  PHQ030  PHAALCHR  PHAALCMN  \
# 0      109263.0     2.0       NaN       NaN     2.0       NaN       NaN
# 1      109264.0     2.0       NaN       NaN     2.0       NaN       NaN
# 2      109265.0     2.0       NaN       NaN     2.0       NaN       NaN
# 3      109266.0     2.0       NaN       NaN     2.0       NaN       NaN
# 4      109269.0     2.0       NaN       NaN     2.0       NaN       NaN
# ...         ...     ...       ...       ...     ...       ...       ...
# 97832   41469.0     2.0       NaN       NaN     2.0       NaN       NaN
# 97833   41471.0     2.0       NaN       NaN     2.0       NaN       NaN
# 97834   41472.0     2.0       NaN       NaN     2.0       NaN       NaN
# 97835   41473.0     2.0       NaN       NaN     2.0       NaN       NaN
# 97836   41474.0     2.0       NaN       NaN     2.0       NaN       NaN
#
#        PHQ040  PHAGUMHR  PHAGUMMN  PHQ050  PHAANTHR  PHAANTMN  PHQ060  \
# ...

# %%
nums = 0
for i in filenames:
    num = pd.read_sas(i).shape[0]
    nums += num
print(nums)
# Out:
# 97837

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97837 entries, 0 to 97836
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      97837 non-null  float64
#  1   PHQ020    94068 non-null  float64
#  2   PHACOFHR  730 non-null    float64
#  3   PHACOFMN  730 non-null    float64
#  4   PHQ030    94068 non-null  float64
#  5   PHAALCHR  296 non-null    float64
#  6   PHAALCMN  296 non-null    float64
#  7   PHQ040    94068 non-null  float64
#  8   PHAGUMHR  2321 non-null   float64
#  9   PHAGUMMN  2321 non-null   float64
#  10  PHQ050    94068 non-null  float64
#  11  PHAANTHR  324 non-null    float64
#  12  PHAANTMN  324 non-null    float64
#  13  PHQ060    94068 non-null  float64
#  14  PHASUPHR  864 non-null    float64
#  15  PHASUPMN  864 non-null    float64
#  16  PHAFSTHR  94061 non-null  float64
#  17  PHAFSTMN  94061 non-null  float64
#  18  PHDSESN   97836 non-null  float64
# ...

# %%
np.sort(total_df['year'].unique())
# Out:
# array([1999, 2001, 2003, 2005, 2007, 2009, 2011, 2013, 2015, 2017],
#       dtype=int64)

# %%
total_df[total_df['year']==1999]['PHAALCHR'].describe()
# Out:
# count    3.300000e+01
# mean     1.003030e+01
# std      4.959113e+00
# min      5.397605e-79
# 25%      6.000000e+00
# 50%      1.100000e+01
# 75%      1.400000e+01
# max      1.700000e+01
# Name: PHAALCHR, dtype: float64

# %%
for i in range(len(total_df['year'].unique())):
    fig, ax = plt.subplots(4,int(len(total_df.columns)/4),figsize=(20,20))
    for k in range(len(total_df.columns)):
        if k < 5:
            total_df[total_df['year']==total_df['year'].unique()[i]][total_df.columns[k]].hist(ax=ax[0,k])
            ax[0,k].set_xlabel(total_df.columns[k])
        elif 5 <= k < 10:
            total_df[total_df['year']==total_df['year'].unique()[i]][total_df.columns[k]].hist(ax=ax[1,k-5])
            ax[1,k-5].set_xlabel(total_df.columns[k])
        elif 10 <= k < 15:
            total_df[total_df['year']==total_df['year'].unique()[i]][total_df.columns[k]].hist(ax=ax[2,k-10])
            ax[2,k-10].set_xlabel(total_df.columns[k])
        elif 15 <= k < 20:
            total_df[total_df['year']==total_df['year'].unique()[i]][total_df.columns[k]].hist(ax=ax[3,k-15])
            ax[3,k-15].set_xlabel(total_df.columns[k])
    fig.suptitle(total_df['year'].unique()[i])
    plt.show()
