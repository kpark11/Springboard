# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np
# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %%
# Just added Latex for my liking. 
from IPython.display import Latex

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
properties.tail()
# Out:
#     Unnamed: 0 City of London Barking & Dagenham  Barnet  Bexley   Brent  \
# 341 2023-05-01         958418             349590  575141  391077  524452
# 342 2023-06-01         951649             346099  575829  390880  531478
# 343 2023-07-01         931176             343430  583479  396718  531425
# 344 2023-08-01         861107             344171  597591  396278  557552
# 345 2023-09-01         807475             345614  584740  396292  565929
#
#     Bromley  Camden Croydon  Ealing  ... NORTH WEST YORKS & THE HUMBER  \
# 341  496393  859267  408859  522224  ...     211169             201807
# 342  497841  871822  406086  529437  ...     213372             208205
# 343  503888  838994  409938  535675  ...     215371             211701
# 344  509263  854042  416583  543218  ...     216895             215241
# 345  502753  810578  430541  554377  ...     218013             210156
#
#     EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  LONDON SOUTH EAST SOUTH WEST  \
# ...

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            345 non-null    datetime64[ns]
#  1   City of London        346 non-null    object
#  2   Barking & Dagenham    346 non-null    object
#  3   Barnet                346 non-null    object
#  4   Bexley                346 non-null    object
#  5   Brent                 346 non-null    object
#  6   Bromley               346 non-null    object
#  7   Camden                346 non-null    object
#  8   Croydon               346 non-null    object
#  9   Ealing                346 non-null    object
#  10  Enfield               346 non-null    object
#  11  Greenwich             346 non-null    object
#  12  Hackney               346 non-null    object
#  13  Hammersmith & Fulham  346 non-null    object
# ...

# %% [markdown]
# **The type of data is object. I will need to turn them into int or float.**
# But first, let's clean the columns and indexes.

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %% [markdown]
# **Renaming the date column**

# %%
properties = properties.rename(columns={'Unnamed: 0':'Dates'})#, errors="raise")
properties.head()
# Out:
#        Dates City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %% [markdown]
# **Setting the date column into the index.**

# %%
properties = properties.set_index('Dates')
properties.head()
# Out:
#            City of London Barking & Dagenham       Barnet       Bexley  \
# Dates
# NaT             E09000001          E09000002    E09000003    E09000004
# 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#                   Brent      Bromley       Camden      Croydon       Ealing  \
# Dates
# NaT           E09000005    E09000006    E09000007    E09000008    E09000009
# 1995-01-01  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069
# 1995-02-01  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551
# 1995-03-01  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288
# 1995-04-01  72965.63094  81124.41227   120097.899  68610.04641  82188.90498
#
# ...

# %% [markdown]
# **The data does not look like it needs to be transposed.**

# %%
properties.isna().sum()
# Out:
# City of London            0
# Barking & Dagenham        0
# Barnet                    0
# Bexley                    0
# Brent                     0
# Bromley                   0
# Camden                    0
# Croydon                   0
# Ealing                    0
# Enfield                   0
# Greenwich                 0
# Hackney                   0
# Hammersmith & Fulham      0
# Haringey                  0
# Harrow                    0
# Havering                  0
# Hillingdon                0
# Hounslow                  0
# Islington                 0
# Kensington & Chelsea      0
# Kingston upon Thames      0
# Lambeth                   0
# Lewisham                  0
# Merton                    0
# Newham                    0
# Redbridge                 0
# Richmond upon Thames      0
# Southwark                 0
# Sutton                    0
# Tower Hamlets             0
# Waltham Forest            0
# Wandsworth                0
# Westminster               0
# ...

# %%
properties = properties.dropna(axis=1,how='all')
properties.head()
# Out:
#            City of London Barking & Dagenham       Barnet       Bexley  \
# Dates
# NaT             E09000001          E09000002    E09000003    E09000004
# 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#                   Brent      Bromley       Camden      Croydon       Ealing  \
# Dates
# NaT           E09000005    E09000006    E09000007    E09000008    E09000009
# 1995-01-01  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069
# 1995-02-01  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551
# 1995-03-01  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288
# 1995-04-01  72965.63094  81124.41227   120097.899  68610.04641  82188.90498
#
# ...

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 346 entries, NaT to 2023-09-01
# Data columns (total 45 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   City of London        346 non-null    object
#  1   Barking & Dagenham    346 non-null    object
#  2   Barnet                346 non-null    object
#  3   Bexley                346 non-null    object
#  4   Brent                 346 non-null    object
#  5   Bromley               346 non-null    object
#  6   Camden                346 non-null    object
#  7   Croydon               346 non-null    object
#  8   Ealing                346 non-null    object
#  9   Enfield               346 non-null    object
#  10  Greenwich             346 non-null    object
#  11  Hackney               346 non-null    object
#  12  Hammersmith & Fulham  346 non-null    object
#  13  Haringey              346 non-null    object
# ...

# %%
properties = properties.rename(index={properties.index[0]:'CensusTrack'})

# %%
properties_t = properties.T

# %%
properties_t.head()
# Out:
# Dates              CensusTrack 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# City of London       E09000001         91448.98487         82202.77314
# Barking & Dagenham   E09000002          50460.2266         51085.77983
# Barnet               E09000003         93284.51832         93190.16963
# Bexley               E09000004         64958.09036         64787.92069
# Brent                E09000005         71306.56698         72022.26197
#
# Dates              1995-03-01 00:00:00 1995-04-01 00:00:00  \
# City of London             79120.70256         77101.20804
# Barking & Dagenham         51268.96956         53133.50526
# Barnet                     92247.52435         90762.87492
# Bexley                     64367.49344         64277.66881
# Brent                      72015.76274         72965.63094
#
# Dates              1995-05-01 00:00:00 1995-06-01 00:00:00  \
# City of London             84409.14932         94900.51244
# Barking & Dagenham         53042.24852         53700.34831
# ...

# %%
properties_t.index.name = 'Boroughs'

# %%
properties_t.head()
# Out:
# Dates              CensusTrack 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# Boroughs
# City of London       E09000001         91448.98487         82202.77314
# Barking & Dagenham   E09000002          50460.2266         51085.77983
# Barnet               E09000003         93284.51832         93190.16963
# Bexley               E09000004         64958.09036         64787.92069
# Brent                E09000005         71306.56698         72022.26197
#
# Dates              1995-03-01 00:00:00 1995-04-01 00:00:00  \
# Boroughs
# City of London             79120.70256         77101.20804
# Barking & Dagenham         51268.96956         53133.50526
# Barnet                     92247.52435         90762.87492
# Bexley                     64367.49344         64277.66881
# Brent                      72015.76274         72965.63094
#
# Dates              1995-05-01 00:00:00 1995-06-01 00:00:00  \
# Boroughs
# City of London             84409.14932         94900.51244
# ...

# %%
properties_t.reset_index(inplace=True)

# %%
properties_t.index
# Out:
# RangeIndex(start=0, stop=45, step=1)

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %% [markdown]
# $\color{red}{\text{Already have renamed it. The ID is called CensusTrack and the Month is Dates in my datasets. Also, the London Boroughs is simply Boroughs}}$

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties_melted = pd.melt(properties_t, id_vars= ['Boroughs', 'CensusTrack'])

# %%
properties_melted.rename(columns={'value':'Average Prices'})
# Out:
#                  Boroughs CensusTrack                Dates Average Prices
# 0          City of London   E09000001  1995-01-01 00:00:00    91448.98487
# 1      Barking & Dagenham   E09000002  1995-01-01 00:00:00     50460.2266
# 2                  Barnet   E09000003  1995-01-01 00:00:00    93284.51832
# 3                  Bexley   E09000004  1995-01-01 00:00:00    64958.09036
# 4                   Brent   E09000005  1995-01-01 00:00:00    71306.56698
# ...                   ...         ...                  ...            ...
# 15520     EAST OF ENGLAND   E12000006  2023-09-01 00:00:00         352509
# 15521              LONDON   E12000007  2023-09-01 00:00:00         537424
# 15522          SOUTH EAST   E12000008  2023-09-01 00:00:00         392174
# 15523          SOUTH WEST   E12000009  2023-09-01 00:00:00         328668
# 15524             England   E92000001  2023-09-01 00:00:00         309602
#
# [15525 rows x 4 columns]

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties_melted = properties_melted.infer_objects()
properties_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15525 entries, 0 to 15524
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Boroughs     15525 non-null  object
#  1   CensusTrack  15525 non-null  object
#  2   Dates        15525 non-null  datetime64[ns]
#  3   value        15525 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 485.3+ KB

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %% [markdown]
# $\color{red}{\text{Already got rid of null values}}$

# %%
properties_melted['Boroughs'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
Boroughs_list = [
'Camden',
'Greenwich',
'Hackney',
'Hammersmith & Fulham',
'Islington',
'Kensington & Chelsea',
'Lambeth',
'Lewisham',
'Southwark',
'Tower Hamlets',
'Wandsworth',
'Westminster',
'Barking & Dagenham',
'Barnet',
'Bexley',
'Brent',
'Bromley',
'Croydon',
'Ealing',
'Enfield',
'Haringey',
'Harrow',
'Havering',
'Hillingdon',
'Hounslow',
'Kingston upon Thames',
'Merton',
'Newham',
'Redbridge',
'Richmond upon Thames',
'Sutton',
'Waltham Forest',
]

# %%
len(Boroughs_list)
# Out:
# 32

# %%
properties_Boroughs = properties_melted[properties_melted['Boroughs'].isin(Boroughs_list)]
properties_Boroughs.describe()
# Out:
#                      Dates         value
# count                11040  1.104000e+04
# mean   2009-05-01 16:00:00  3.261663e+05
# min    1995-01-01 00:00:00  5.046023e+04
# 25%    2002-03-01 00:00:00  1.791270e+05
# 50%    2009-05-01 00:00:00  2.781777e+05
# 75%    2016-07-01 00:00:00  4.300986e+05
# max    2023-09-01 00:00:00  1.517127e+06
# std                    NaN  2.159243e+05

# %%
properties_Boroughs['Boroughs'].unique()
# Out:
# array(['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley',
#        'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney',
#        'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster'],
#       dtype=object)

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
properties_Boroughs.head()
# Out:
#              Boroughs CensusTrack      Dates        value
# 1  Barking & Dagenham   E09000002 1995-01-01  50460.22660
# 2              Barnet   E09000003 1995-01-01  93284.51832
# 3              Bexley   E09000004 1995-01-01  64958.09036
# 4               Brent   E09000005 1995-01-01  71306.56698
# 5             Bromley   E09000006 1995-01-01  81671.47692

# %%
properties_Boroughs.rename(columns={'value':'Average Prices'},inplace=True)
properties_Boroughs.head()
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_7768\2117348892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   properties_Boroughs.rename(columns={'value':'Average Prices'},inplace=True)
#              Boroughs CensusTrack      Dates  Average Prices
# 1  Barking & Dagenham   E09000002 1995-01-01     50460.22660
# 2              Barnet   E09000003 1995-01-01     93284.51832
# 3              Bexley   E09000004 1995-01-01     64958.09036
# 4               Brent   E09000005 1995-01-01     71306.56698
# 5             Bromley   E09000006 1995-01-01     81671.47692

# %%
properties_Boroughs['Average Prices'] = pd.to_numeric(properties_Boroughs['Average Prices'])
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_7768\4046935741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   properties_Boroughs['Average Prices'] = pd.to_numeric(properties_Boroughs['Average Prices'])

# %%
fig, ax = plt.subplots()
for i in properties_Boroughs['Boroughs'].unique():
    properties_Boroughs[properties_Boroughs['Boroughs']==i].plot(x='Dates',
                                                                 y='Average Prices',
                                                                 title=i,
                                                                 xlabel='Dates',
                                                                 ylabel='Average Prices',
                                                                 )
    plt.show()

# %% [markdown]
# **Or I can overlay plots for all the Boroughs**

# %%
fig, ax = plt.subplots()
for i in properties_Boroughs['Boroughs'].unique():
    plotData = properties_Boroughs[properties_Boroughs['Boroughs']==i]
    plt.plot(plotData['Dates'],plotData['Average Prices'])
plt.title('Average Prices vs. Dates')
plt.xlabel('Dates')
plt.ylabel('Average Prices')
plt.legend(properties_Boroughs['Boroughs'].unique(),bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
properties_Boroughs['Year'] = properties_Boroughs['Dates'].dt.year
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_7768\668379106.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   properties_Boroughs['Year'] = properties_Boroughs['Dates'].dt.year

# %%
properties_Boroughs.head()
# Out:
#              Boroughs CensusTrack      Dates  Average Prices  Year
# 1  Barking & Dagenham   E09000002 1995-01-01     50460.22660  1995
# 2              Barnet   E09000003 1995-01-01     93284.51832  1995
# 3              Bexley   E09000004 1995-01-01     64958.09036  1995
# 4               Brent   E09000005 1995-01-01     71306.56698  1995
# 5             Bromley   E09000006 1995-01-01     81671.47692  1995

# %% [markdown]
# **We can calculate the mean for each year.**

# %%
properties_Boroughs_yearly = properties_Boroughs.groupby(by=['Boroughs','Year'])['Average Prices'].mean()
properties_Boroughs_yearly.head()
# Out:
# Boroughs            Year
# Barking & Dagenham  1995    51817.969390
#                     1996    51718.192690
#                     1997    55974.262309
#                     1998    60285.821083
#                     1999    65320.934441
# Name: Average Prices, dtype: float64

# %%
properties_Boroughs_yearly = properties_Boroughs_yearly.reset_index()

# %%
properties_Boroughs_yearly.head()
# Out:
#              Boroughs  Year  Average Prices
# 0  Barking & Dagenham  1995    51817.969390
# 1  Barking & Dagenham  1996    51718.192690
# 2  Barking & Dagenham  1997    55974.262309
# 3  Barking & Dagenham  1998    60285.821083
# 4  Barking & Dagenham  1999    65320.934441

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(df):
    old = df['Average Prices'][df['Year']==1998].values
    recent = df['Average Prices'][df['Year']==2018].values
    ratio = np.divide(recent,old)
    return float(ratio)

# %%
ratio_Boroughs = {}
for boroughs in properties_Boroughs_yearly['Boroughs'].unique():
    ratio = create_price_ratio(properties_Boroughs_yearly[properties_Boroughs_yearly['Boroughs']==boroughs])
    ratio_Boroughs[boroughs] = ratio

# %%
print(ratio_Boroughs)
# Out:
# {'Barking & Dagenham': 4.89661861291754, 'Barnet': 4.358195917538044, 'Bexley': 4.248977046127877, 'Brent': 4.8945544971392865, 'Bromley': 4.094784685333876, 'Camden': 4.935353408884261, 'Croydon': 4.201100280024766, 'Ealing': 4.311450902121834, 'Enfield': 4.263471583495811, 'Greenwich': 4.7630363473291935, 'Hackney': 6.198285561008663, 'Hammersmith & Fulham': 4.13779810193623, 'Haringey': 5.134624964136042, 'Harrow': 4.0591964329643195, 'Havering': 4.325230371335307, 'Hillingdon': 4.2002730803844575, 'Hounslow': 3.976409106143329, 'Islington': 4.844048012802297, 'Kensington & Chelsea': 5.082465066092464, 'Kingston upon Thames': 4.270549521484271, 'Lambeth': 4.957751163514062, 'Lewisham': 5.449221041059686, 'Merton': 4.741273313294603, 'Newham': 5.305390437201879, 'Redbridge': 4.471182006097364, 'Richmond upon Thames': 4.005161895721457, 'Southwark': 5.516485302379378, 'Sutton': 4.118522608573157, 'Tower Hamlets': 4.62670104006116, 'Waltham Forest': 5.83475580932281, 'Wandsworth': 4.
# ...

# %%
ratio_Boroughs_sorted = dict(sorted(ratio_Boroughs.items(), key=lambda x:x[1],reverse=True))

# %%
print(ratio_Boroughs_sorted)
# Out:
# {'Hackney': 6.198285561008663, 'Waltham Forest': 5.83475580932281, 'Southwark': 5.516485302379378, 'Lewisham': 5.449221041059686, 'Westminster': 5.353565392605412, 'Newham': 5.305390437201879, 'Haringey': 5.134624964136042, 'Kensington & Chelsea': 5.082465066092464, 'Lambeth': 4.957751163514062, 'Camden': 4.935353408884261, 'Barking & Dagenham': 4.89661861291754, 'Brent': 4.8945544971392865, 'Islington': 4.844048012802297, 'Greenwich': 4.7630363473291935, 'Wandsworth': 4.75770934773927, 'Merton': 4.741273313294603, 'Tower Hamlets': 4.62670104006116, 'Redbridge': 4.471182006097364, 'Barnet': 4.358195917538044, 'Havering': 4.325230371335307, 'Ealing': 4.311450902121834, 'Kingston upon Thames': 4.270549521484271, 'Enfield': 4.263471583495811, 'Bexley': 4.248977046127877, 'Croydon': 4.201100280024766, 'Hillingdon': 4.2002730803844575, 'Hammersmith & Fulham': 4.13779810193623, 'Sutton': 4.118522608573157, 'Bromley': 4.094784685333876, 'Harrow': 4.0591964329643195, 'Richmond upon Thames': 
# ...

# %%
plt.figure().set_figheight(10)
plt.figure().set_figwidth(15)
plt.bar(ratio_Boroughs_sorted.keys() , ratio_Boroughs_sorted.values())
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# **Conclusion:**
#
# By looking at the ratio between the 2018 and 1998 year average price, Hackney had the highest and Hounslow had the lowest. By consulting the map, we can see that Hackney is in the inner circle close to the center. Waltham Forest had the second highest ratio, which is right above Hackney. Southwark is the opposite of Hackney in the inner circle, close to the center as well. Fourth highest is Lewisham, being the inner circle and right next to Southwark. Areas outside of the inner circle, such as Hounslow, Richmond, Harrow, and Hillingdon, are among the bottom of the ratios. However, the ratio and the average price vs. dates graph reveal that there are consistent growth of average price.
